# %%
# 크롬 드라이버 가져오기
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome() #executable_path="chromedriver"

driver.get("https://www.naver.com")

# CSR 에서 페이지 렌더링 시간을 줘야함
time.sleep(3)

searchValue = input("검색어 입력 : ")

# searchInput = driver.find_element_by_css_selector("#input")
# 4버전 부터 변경점이 많음
searchInput = driver.find_element(by=By.CSS_SELECTOR, value="#query") # id로 html요소를 가져옴 /#= id요소 . = class
searchInput.send_keys(searchValue) # input에입력한 값이 실제 창 검색창에 입력
searchInput.send_keys(Keys.RETURN) # 위의것을 실제로 검색(RETURN = enter키)

time.sleep(2)

driver.find_element(by=By.XPATH, value='//*[@id="lnb"]/div[1]/div/div[1]/div/div[2]/div[2]/a/span').click()
time.sleep(1)
driver.find_element(by=By.XPATH, value='//*[@id="lnb"]/div[1]/div/div[1]/div/div[1]/div[7]/a').click()
time.sleep(2)
newsTitles = driver.find_elements(by=By.CSS_SELECTOR, value=".news_tit")
for title in newsTitles:
    print(title.text)

for i in range(2, 5):
    driver.find_element(by=By.XPATH, value=f'//*[@id="main_pack"]/div[2]/div/div/a[{i}]').click()
    time.sleep(2)
    # newsTitles = driver.find_elements(by=By.CSS_SELECTOR, value=".news_tit")
    # for title in newsTitles:
    #     print(title.get_attribute("name='href"))
    newsIamages = driver.find_elements(by=By.CSS_SELECTOR, value=".dsc_thumb .thumb")
    for img in newsIamages:
        print(img.get_attribute(name="src"))

f'//*[@id="main_pack"]/div[2]/div/div/a[{"3"}]'


# 웹툰 홈 -> 웹툰 페이지 -> 월 ~ 일까지의 데이터
webtoonList = [
    {
        "dayOfTheWeek": "월",
        "webtoon": [
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
        ]
    },
    {
        "dayOfTheWeek": "화",
        "webtoon": [
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
        ]
    },
    {
        "dayOfTheWeek": "수",
        "webtoon": [
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
        ]
    },
    {
        "dayOfTheWeek": "목",
        "webtoon": [
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
        ]
    },
    {
        "dayOfTheWeek": "금",
        "webtoon": [
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
            {
                "title": "",
                "author": "",
                "grade": 9.87,
                "postImage": ""
            },
        ]
    },
]
# Out:
# 삼성전자, 12년 연속 '동반성장 최우수 기업' 선정
# 메모리 불황 끝이 보인다… 삼성전자·SK하이닉스 3분기 실적 개선 기대
# 삼성전자·SK텔레콤·네이버 등 3년 연속 '동반성장' 최우수 등급
# 유진투자 "삼성전자 3분기 영업이익 1조6천억원 예상"
# [기업] 삼성전자·SK텔레콤 등 41개 기업 동반성장 '최우수'
# 드디어…국내 최장수 반도체 ETF들, 삼성전자 담는다
# “삼성전자 SK하이닉스 투자비중확대”…재고 줄고 수요 올해 바닥
# ‘동반성장 최우수 기업’ 역대 최다… 삼성전자 12년 연속
# 삼성전자-SKT 등 28곳 ‘동반성장 명예기업’
# ‘RE100 선언 1년’ 삼성전자, 성적표는 ‘글쎄…’
# https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F015%2F2023%2F09%2F19%2F4893398.jpg&type=ff264_180&expire=2&refresh=true
# https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F015%2F2023%2F09%2F19%2F4893391.jpg&type=ff264_180&expire=2&refresh=true
# https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F005%2F2023%2F09%2F19%2F1639151.jpg&type=ff264_180&expire=2&refresh=true
# ...
