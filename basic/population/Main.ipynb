# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

data = pd.read_csv("202108_202208_주민등록인구및세대현황_월간.csv", encoding="cp949")
print(data.columns)
print(data.index)
print(data)

# 연도별 행정구역별 거주가 인구
print(data.iloc[1, 0])
print(data.iloc[1, range(1, len(data.columns), 6)]) # range(x부터 ,y까지, z만큼점프 하면서)

# 세대당 인구
print(f"""
    {data.query('행정구역.str.contains("가야제1동")')}
""")
rowIndex = data.query('행정구역.str.contains("가야제1동")').index.values[0]
# dataFrame안에 있는 query( 조건 )
print(data.iloc[rowIndex, 0])
print(data.iloc[rowIndex, range(3, len(data.columns), 6)])
